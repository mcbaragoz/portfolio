# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [raw]
# transactions_control_1 = pd.read_csv('Проект_3_transactions_control_1.csv', sep = ';')
# transactions_control_2 = pd.read_csv('Проект_3_transactions_control_2.csv', sep = ';')
# transactions_test = pd.read_csv('Проект_3_transactions_test.csv', sep = ';)
# transactions_control_2

# %%
transactions_control_1 = pd.read_csv('Проект_3_transactions_control_1.csv', sep = ';')
transactions_control_2 = pd.read_csv('Проект_3_transactions_control_2.csv', sep = ';')
transactions_test = pd.read_csv('Проект_3_transactions_test.csv', sep = ';')
users_control_1 = pd.read_csv('Проект_3_users_control_1.csv', sep = ';')
users_control_2 = pd.read_csv('Проект_3_users_control_2.csv', sep = ';')
users_test = pd.read_csv('Проект_3_users_test.csv', sep = ';') 
users_control_1
# Out:
#             uid  age  attraction_coeff  coins                   country  \
# 0     892319115   25               435    NaN  United States of America
# 1     891248523   29               500    NaN  United States of America
# 2     891670932   33               800    NaN                    France
# 3     891060786   26                 0    NaN                 Argentina
# 4     892006554   35               294    NaN  United States of America
# ...         ...  ...               ...    ...                       ...
# 4335  892022304   26               227    NaN  United States of America
# 4336  891905022   38               200    NaN                 Argentina
# 4337  891304722   49               411    NaN  United States of America
# 4338  891302328   27                 0    NaN  United States of America
# 4339  891182532   31              1000    NaN  United States of America
#
#                                   visit_days  gender  age_filter_start  \
# ...

# %%
#первая платежная система
transactions_control_1.product_type.
# Out:
#            uid country            joined_at              paid_at  revenue  \
# 0  891319275.0  France  2017-05-11 19:57:00  2017-12-11 21:57:00  12727.0
# 1  892421826.0  Israel  2017-10-14 12:46:00  2017-10-23 12:54:00  14586.0
# 2  891822480.0   Italy  2017-10-26 22:27:00  2017-12-11 20:59:00   1911.0
# 3  891367521.0   Italy  2017-05-11 02:37:00  2017-06-11 19:15:00   1456.0
# 4  892207959.0  France  2017-10-18 18:30:00  2017-12-11 12:03:00   1261.0
#
#    payment_id        from_page   product_type
# 0       147.0  trial_vip_popup  trial_premium
# 1       147.0  trial_vip_popup  trial_premium
# 2        19.0             none          coins
# 3       127.0         sympathy     other_type
# 4        19.0      empty_likes          coins

# %% [markdown]
# 1. Проверить сколько людей из всех стран из тестовой группы купило trial_premium и premium no trial

# %%
users_test
# Out:
#             uid  age  attraction_coeff  coins                   country  \
# 0     892309896   27               685    NaN  United States of America
# 1     892044516   27                 0    NaN                   Germany
# 2     892185708   45                44    NaN                    Israel
# 3     892130292   32                 0    NaN  United States of America
# 4     891406035   27              1000    NaN                    France
# ...         ...  ...               ...    ...                       ...
# 4303  891078639   17               895    NaN  United States of America
# 4304  891188733   27               866    NaN  United States of America
# 4305  891293718   48                 0    NaN                 Argentina
# 4306  891192357   32                 0    NaN                 Australia
# 4307  891668910   35               575    NaN      United Arab Emirates
#
#                                              visit_days  gender  \
# ...

# %%
transactions_test.query('product_type == "premium_no_trial"')
# Out:
#            uid                         country            joined_at  \
# 5    892426491        United States of America  2017-10-14 10:13:00
# 6    891558921        United States of America  2017-01-11 03:07:00
# 11   891861048                          Canada  2017-10-26 02:55:00
# 12   891178380                           Spain  2017-08-11 03:54:00
# 21   891312873                           Italy  2017-05-11 21:22:00
# ..         ...                             ...                  ...
# 262  891692940        United States of America  2017-10-29 15:40:00
# 265  891572565            United Arab Emirates  2017-10-31 20:40:00
# 266  891478452            United Arab Emirates  2017-02-11 23:29:00
# 267  891414915                       Argentina  2017-04-11 09:06:00
# 269  891447105  United Kingdom (Great Britain)  2017-03-11 17:05:00
#
#                  paid_at  revenue  payment_id          from_page  \
# 5    2017-10-15 22:39:00    12597         147  autoreply_message
# ...

# %%
transactions_control_2.query('product_type == "premium_no_trial"')
# Out:
#            uid                         country            joined_at  \
# 1    892186737                           Chile  2017-10-19 06:03:00
# 4    891592941                     Switzerland  2017-10-31 12:40:00
# 5    892245918                          France  2017-10-17 21:05:00
# 7    891267564                        Portugal  2017-06-11 15:06:00
# 9    892080081                     Switzerland  2017-10-21 15:15:00
# ..         ...                             ...                  ...
# 316  891393735                           Spain  2017-04-11 17:31:00
# 317  892053750        United States of America  2017-10-22 00:46:00
# 320  892032072  United Kingdom (Great Britain)  2017-10-22 14:21:00
# 322  891435993                          Canada  2017-03-11 21:08:00
# 327  891459291                           Spain  2017-03-11 11:43:00
#
#                  paid_at  revenue  payment_id          from_page  \
# 1    2017-04-11 08:53:00     4732         147           promo_09
# ...

# %%
users_test.age.describe()
# Out:
# count    4308.000000
# mean       31.889276
# std        10.245287
# min        16.000000
# 25%        25.000000
# 50%        30.000000
# 75%        38.000000
# max        99.000000
# Name: age, dtype: float64

# %%
users_control_2.describe()
# Out:
#                 uid          age  attraction_coeff       coins       gender  \
# count  4.264000e+03  4264.000000       4264.000000   61.000000  4264.000000
# mean   8.917694e+08    32.046201        317.957317   18.147541     0.954268
# std    2.520759e+06    10.170721        326.191737   35.439543     0.208927
# min    8.910509e+08    16.000000          0.000000    1.000000     0.000000
# 25%    8.913453e+08    25.000000          0.000000    4.000000     1.000000
# 50%    8.917205e+08    30.000000        250.000000   10.000000     1.000000
# 75%    8.920735e+08    38.000000        548.500000   20.000000     1.000000
# max    1.053059e+09    99.000000       1000.000000  271.000000     1.000000
#
#        age_filter_start  age_filter_end   views_count  was_premium  \
# count       4264.000000     4264.000000   4264.000000        411.0
# mean          26.954268       38.906895     45.064493          1.0
# std            9.546657       15.955574    318.188992          0.0
# ...

# %%
users_test.describe()
# Out:
#                 uid          age  attraction_coeff        coins       gender  \
# count  4.308000e+03  4308.000000       4308.000000    49.000000  4308.000000
# mean   8.917437e+08    31.889276        316.411328   229.836735     0.953110
# std    4.547670e+05    10.245287        323.373725  1205.819471     0.211427
# min    8.910511e+08    16.000000          0.000000     1.000000     0.000000
# 25%    8.913621e+08    25.000000          0.000000     4.000000     1.000000
# 50%    8.917290e+08    30.000000        250.000000     9.000000     1.000000
# 75%    8.920952e+08    38.000000        520.250000    72.000000     1.000000
# max    9.051586e+08    99.000000       1000.000000  8466.000000     1.000000
#
#        age_filter_start  age_filter_end   views_count  was_premium  \
# count       4308.000000     4308.000000   4308.000000        408.0
# mean          26.701486       38.248839     50.391133          1.0
# std            9.390851       15.344562    318.676437          0.0
# ...

# %%
d1 = users_test.groupby('country', as_index = False).agg({'uid': 'count'}).sort_values('uid', ascending = False)
d1
# Out:
#                            country   uid
# 48        United States of America  1450
# 1                        Argentina   396
# 13                          France   359
# 24                           Italy   323
# 40                           Spain   301
# 8                            Chile   272
# 46            United Arab Emirates   226
# 16                         Germany   209
# 47  United Kingdom (Great Britain)   169
# 7                           Canada   137
# 23                          Israel   106
# 4                          Belgium    92
# 35                        Portugal    91
# 2                        Australia    62
# 41                     Switzerland    35
# 45                         Ukraine    15
# 28                          Mexico     7
# 38              Russian Federation     7
# 44                          Turkey     5
# 19                           India     4
# 20                       Indonesia     4
# 30                         Morocco     3
# ...

# %%
d2 = users_control_2.groupby('country', as_index = False).agg({'uid': 'count'}).sort_values('uid', ascending = False)
d2
# Out:
#                            country   uid
# 43        United States of America  1486
# 0                        Argentina   397
# 12                          France   376
# 35                           Spain   310
# 18                           Italy   293
# 6                            Chile   286
# 41            United Arab Emirates   211
# 14                         Germany   202
# 42  United Kingdom (Great Britain)   146
# 5                           Canada   134
# 31                        Portugal   100
# 4                          Belgium    90
# 17                          Israel    78
# 1                        Australia    51
# 36                     Switzerland    35
# 40                         Ukraine    18
# 33              Russian Federation     8
# 38                          Turkey     5
# 25                         Morocco     5
# 24                          Mexico     4
# 8                         Colombia     2
# 2                          Austria     2
# ...

# %%
d3 = d1.merge(d2, on = 'country', how = 'left')
d3
# Out:
#                            country  uid_x   uid_y
# 0         United States of America   1450  1486.0
# 1                        Argentina    396   397.0
# 2                           France    359   376.0
# 3                            Italy    323   293.0
# 4                            Spain    301   310.0
# 5                            Chile    272   286.0
# 6             United Arab Emirates    226   211.0
# 7                          Germany    209   202.0
# 8   United Kingdom (Great Britain)    169   146.0
# 9                           Canada    137   134.0
# 10                          Israel    106    78.0
# 11                         Belgium     92    90.0
# 12                        Portugal     91   100.0
# 13                       Australia     62    51.0
# 14                     Switzerland     35    35.0
# 15                         Ukraine     15    18.0
# 16                          Mexico      7     4.0
# 17              Russian Federation      7     8.0
# ...
